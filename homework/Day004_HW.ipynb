# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11697115024","type":"PushEvent","actor":{"id":22668228,"login":"Spirosvw","display_login":"Spirosvw","gravatar_id":"","url":"https://api.github.com/users/Spirosvw","avatar_url":"https://avatars.githubusercontent.com/u/22668228?"},"repo":{"id":245397100,"name":"Spirosvw/site-gr","url":"https://api.github.com/repos/Spirosvw/site-gr"},"payload":{"push_id":4728196663,"size":1,"distinct_size":1,"ref":"refs/heads/add-tutor","head":"705cbb3ff8ae2d8c407d399ff388672f973a16da","before":"b6da529859174942ec60f98c7d21b099e359c045","commits":[{"sha":"705cbb3ff8ae2d8c407d399ff388672f973a16da","author":{"email":"p15verg@ionio.gr","name":"Spiros Vergis"},"message":"Add files via upload","distinct":true,"url":"https://api.github.com/repos/Spirosvw/site-gr/commits/705cbb3ff8ae2d8c407d399ff388672f973a16da"}]},"public":true,"created_at":"2020-03-06T11:06:37Z"},{"id":"11697115032","type":"PullRequestReviewCommentEvent","actor":{"id":60605747,"login":"JamBai2812","display_login":"JamBai2812","grav
# ...

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '11697115024',
#   'type': 'PushEvent',
#   'actor': {'id': 22668228,
#    'login': 'Spirosvw',
#    'display_login': 'Spirosvw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Spirosvw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22668228?'},
#   'repo': {'id': 245397100,
#    'name': 'Spirosvw/site-gr',
#    'url': 'https://api.github.com/repos/Spirosvw/site-gr'},
#   'payload': {'push_id': 4728196663,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/add-tutor',
#    'head': '705cbb3ff8ae2d8c407d399ff388672f973a16da',
#    'before': 'b6da529859174942ec60f98c7d21b099e359c045',
#    'commits': [{'sha': '705cbb3ff8ae2d8c407d399ff388672f973a16da',
#      'author': {'email': 'p15verg@ionio.gr', 'name': 'Spiros Vergis'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Spirosvw/site-gr/commits/705cbb3ff8ae2d8c407d399ff388672f973a16da'}]},
#   'public': True,
# ...

# %%
payload = {'key1': 'value1','key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e623097-18d15f53d7e915e08b62b080'},
#  'origin': '140.113.136.219',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6230c1-5409e83a75726a4038c99044'},
#  'json': None,
#  'origin': '140.113.136.219',
#  'url': 'http://httpbin.org/post'}

# %%
json.loads會進行分類

# %%
r = requests.get('https://alexwohlbruck.github.io/cat-facts/')
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n  <head>\n    <meta charset="UTF-8">\n\n<!-- Begin Jekyll SEO tag v2.6.1 -->\n<title>cat-facts | Daily cat facts!</title>\n<meta name="generator" content="Jekyll v3.8.5" />\n<meta property="og:title" content="cat-facts" />\n<meta property="og:locale" content="en_US" />\n<meta name="description" content="Daily cat facts!" />\n<meta property="og:description" content="Daily cat facts!" />\n<link rel="canonical" href="https://alexwohlbruck.github.io/cat-facts/" />\n<meta property="og:url" content="https://alexwohlbruck.github.io/cat-facts/" />\n<meta property="og:site_name" content="cat-facts" />\n<script type="application/ld+json">\n{"@type":"WebSite","url":"https://alexwohlbruck.github.io/cat-facts/","name":"cat-facts","headline":"cat-facts","description":"Daily cat facts!","@context":"https://schema.org"}</script>\n<!-- End Jekyll SEO tag -->\n\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta name="theme-color"
# ...

# %%
r = requests.post('https://alexwohlbruck.github.io/cat-facts/', data = {'key':'value'})
json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-b7f8c9a2827b> in <module>
#       1 r = requests.post('https://alexwohlbruck.github.io/cat-facts/', data = {'key':'value'})
# ----> 2 json.loads(r.text)
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
r = requests.get('https://tw.hotels.com')

# %%
print(r.status_code)
# Out:
# 200

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xml:lang="zh-TW" lang="zh-TW" class="no-js intl-zh_TW no-touch lt-ie9 old-ie-css ie8" ><![endif]-->
# <!--[if IE 9]><html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xml:lang="zh-TW" lang="zh-TW" class="responsive-css no-js intl-zh_TW ie9" ><![endif]-->
# <!--[if gt IE 9]><!--><html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xml:lang="zh-TW" lang="zh-TW" class="responsive-css no-js intl-zh_TW" ><!--<![endif]-->
# ...

# %%
r = requests.post('https://tw.hotels.com', data = {'key':'value'})
json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-17-f55bbdc0cb9e> in <module>
#       1 r = requests.post('https://tw.hotels.com', data = {'key':'value'})
# ----> 2 json.loads(r.text)
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...
